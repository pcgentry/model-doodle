# %% [markdown]
# # “classifier”, “regressor”, “cluster”, “transformer” OH MY

# %%
from sklearn.utils import all_estimators

estimator_types = ['classifier', 'regressor', 'cluster', 'transformer']
estimator_list = all_estimators(type_filter='classifier')

estimators = {}

for estimator_type in estimator_types:
    all_things = []
    for name, RegressorClass in estimator_list:
        try:
            print(f'{estimator_type}: {name}')
            reg = RegressorClass()
            all_regs.append(reg)
        except Exception as e:
            pass
    estimators[estimator_type] = all_things
# Out:
# classifier: AdaBoostClassifier
# classifier: BaggingClassifier
# classifier: BernoulliNB
# classifier: CalibratedClassifierCV
# classifier: CategoricalNB
# classifier: ClassifierChain
# classifier: ComplementNB
# classifier: DecisionTreeClassifier
# classifier: DummyClassifier
# classifier: ExtraTreeClassifier
# classifier: ExtraTreesClassifier
# classifier: GaussianNB
# classifier: GaussianProcessClassifier
# classifier: GradientBoostingClassifier
# classifier: HistGradientBoostingClassifier
# classifier: KNeighborsClassifier
# classifier: LabelPropagation
# classifier: LabelSpreading
# classifier: LinearDiscriminantAnalysis
# classifier: LinearSVC
# classifier: LogisticRegression
# classifier: LogisticRegressionCV
# classifier: MLPClassifier
# classifier: MultiOutputClassifier
# classifier: MultinomialNB
# classifier: NearestCentroid
# classifier: NuSVC
# classifier: OneVsOneClassifier
# classifier: OneVsRestClassifier
# classifier: OutputCodeClassifier
# classifier: PassiveAggressiveClassifier
# classifier: Perceptron
# classifier: QuadraticDiscriminantAnalysis
# classifier: RadiusNeighborsClassifier
# classifier: RandomForestClassifier
# classifier: RidgeClassifier
# classifier: RidgeClassifierCV
# classifier: SGDClassifier
# classifier: SVC
# classifier: StackingClassifier
# classifier: VotingClassifier
# regressor: AdaBoostClassifier
# regressor: BaggingClassifier
# regressor: BernoulliNB
# regressor: CalibratedClassifierCV
# regressor: CategoricalNB
# regressor: ClassifierChain
# regressor: ComplementNB
# regressor: DecisionTreeClassifier
# regressor: DummyClassifier
# regressor: ExtraTreeClassifier
# regressor: ExtraTreesClassifier
# regressor: GaussianNB
# regressor: GaussianProcessClassifier
# regressor: GradientBoostingClassifier
# regressor: HistGradientBoostingClassifier
# regressor: KNeighborsClassifier
# regressor: LabelPropagation
# regressor: LabelSpreading
# regressor: LinearDiscriminantAnalysis
# regressor: LinearSVC
# regressor: LogisticRegression
# regressor: LogisticRegressionCV
# regressor: MLPClassifier
# regressor: MultiOutputClassifier
# regressor: MultinomialNB
# regressor: NearestCentroid
# regressor: NuSVC
# regressor: OneVsOneClassifier
# regressor: OneVsRestClassifier
# regressor: OutputCodeClassifier
# regressor: PassiveAggressiveClassifier
# regressor: Perceptron
# regressor: QuadraticDiscriminantAnalysis
# regressor: RadiusNeighborsClassifier
# regressor: RandomForestClassifier
# regressor: RidgeClassifier
# regressor: RidgeClassifierCV
# regressor: SGDClassifier
# regressor: SVC
# regressor: StackingClassifier
# regressor: VotingClassifier
# cluster: AdaBoostClassifier
# cluster: BaggingClassifier
# cluster: BernoulliNB
# cluster: CalibratedClassifierCV
# cluster: CategoricalNB
# cluster: ClassifierChain
# cluster: ComplementNB
# cluster: DecisionTreeClassifier
# cluster: DummyClassifier
# cluster: ExtraTreeClassifier
# cluster: ExtraTreesClassifier
# cluster: GaussianNB
# cluster: GaussianProcessClassifier
# cluster: GradientBoostingClassifier
# cluster: HistGradientBoostingClassifier
# cluster: KNeighborsClassifier
# cluster: LabelPropagation
# cluster: LabelSpreading
# cluster: LinearDiscriminantAnalysis
# cluster: LinearSVC
# cluster: LogisticRegression
# cluster: LogisticRegressionCV
# cluster: MLPClassifier
# cluster: MultiOutputClassifier
# cluster: MultinomialNB
# cluster: NearestCentroid
# cluster: NuSVC
# cluster: OneVsOneClassifier
# cluster: OneVsRestClassifier
# cluster: OutputCodeClassifier
# cluster: PassiveAggressiveClassifier
# cluster: Perceptron
# cluster: QuadraticDiscriminantAnalysis
# cluster: RadiusNeighborsClassifier
# cluster: RandomForestClassifier
# cluster: RidgeClassifier
# cluster: RidgeClassifierCV
# cluster: SGDClassifier
# cluster: SVC
# cluster: StackingClassifier
# cluster: VotingClassifier
# transformer: AdaBoostClassifier
# transformer: BaggingClassifier
# transformer: BernoulliNB
# transformer: CalibratedClassifierCV
# transformer: CategoricalNB
# transformer: ClassifierChain
# transformer: ComplementNB
# transformer: DecisionTreeClassifier
# transformer: DummyClassifier
# transformer: ExtraTreeClassifier
# transformer: ExtraTreesClassifier
# transformer: GaussianNB
# transformer: GaussianProcessClassifier
# transformer: GradientBoostingClassifier
# transformer: HistGradientBoostingClassifier
# transformer: KNeighborsClassifier
# transformer: LabelPropagation
# transformer: LabelSpreading
# transformer: LinearDiscriminantAnalysis
# transformer: LinearSVC
# transformer: LogisticRegression
# transformer: LogisticRegressionCV
# transformer: MLPClassifier
# transformer: MultiOutputClassifier
# transformer: MultinomialNB
# transformer: NearestCentroid
# transformer: NuSVC
# transformer: OneVsOneClassifier
# transformer: OneVsRestClassifier
# transformer: OutputCodeClassifier
# transformer: PassiveAggressiveClassifier
# transformer: Perceptron
# transformer: QuadraticDiscriminantAnalysis
# transformer: RadiusNeighborsClassifier
# transformer: RandomForestClassifier
# transformer: RidgeClassifier
# transformer: RidgeClassifierCV
# transformer: SGDClassifier
# transformer: SVC
# transformer: StackingClassifier
# transformer: VotingClassifier
